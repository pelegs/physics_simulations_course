# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
points = np.load("tests/grid_with_hole_1.npy")

# %%
plt.plot(points[:,0], points[:,1], marker="o", color="blue", linestyle="None")
