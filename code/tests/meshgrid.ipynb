# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
nx, ny = (5, 3)
x = np.linspace(0, 1, nx)
y = np.linspace(0, 1, ny)
xv, yv = np.meshgrid(x, y, indexing="xy")

# %%
plt.plot(xv, yv, marker="o", color="blue", linestyle="None")
